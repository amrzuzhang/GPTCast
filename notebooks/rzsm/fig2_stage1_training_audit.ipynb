# %% [markdown]
# # 补充图 S1 第一阶段训练审计
#
# 这个 notebook 生成第一阶段 tokenizer 的训练审计图。
#
# 建议用途：
# - 放在补充材料中，作为 Figure S1
# - 用于说明训练稳定性
# - 不建议替代主文里的定量主结果图

# %%
import sys
from pathlib import Path


def find_gptcast_root(start: Path) -> Path:
    p = start.resolve()
    for _ in range(8):
        if (p / 'gptcast').is_dir():
            return p
        if (p / 'GPTCast' / 'gptcast').is_dir():
            return (p / 'GPTCast').resolve()
        p = p.parent
    return start.resolve()


ROOT = find_gptcast_root(Path.cwd())
NOTEBOOK_DIR = ROOT / 'notebooks' / 'rzsm'
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))
if str(NOTEBOOK_DIR) not in sys.path:
    sys.path.insert(0, str(NOTEBOOK_DIR))

from soilcast_stage1_paper_figures import plot_stage1_training_audit
# Out:
# /home/ang/miniconda3/envs/gptcast/lib/python3.12/site-packages/lightning/fabric/__init__.py:41: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.

# %%
run_map = {
    'old_mae_tokenizer': ROOT / 'logs' / 'train' / 'runs' / '2026-03-13_10-47-01',
    'new_phuber_tokenizer': ROOT / 'logs' / 'train' / 'runs' / '2026-03-13_10-49-49',
}
output_dir = ROOT / 'outputs' / 'stage1_tokenizer_paper'
training_df, training_summary = plot_stage1_training_audit(
    run_map=run_map,
    output_dir=output_dir,
    save_stem='figS1_stage1_training_audit',
)
print('已生成补充训练审计图:', training_summary['png_path'])
training_df

print('\n建议英文 caption：')
print(training_summary['caption_en'])
print('\n建议中文 caption：')
print(training_summary['caption_zh'])
# Out:
# {'png_path': '/home/ang/GPTCast/outputs/stage1_tokenizer_paper/fig2_stage1_training_audit.png', 'pdf_path': '/home/ang/GPTCast/outputs/stage1_tokenizer_paper/fig2_stage1_training_audit.pdf', 'csv_path': '/home/ang/GPTCast/outputs/stage1_tokenizer_paper/fig2_stage1_training_audit.csv', 'runs': ['old_mae_tokenizer', 'new_phuber_tokenizer']}
#               run_label                                            run_dir  \
# 0     old_mae_tokenizer  /home/ang/GPTCast/logs/train/runs/2026-03-13_1...
# 1  new_phuber_tokenizer  /home/ang/GPTCast/logs/train/runs/2026-03-13_1...
# 2     old_mae_tokenizer  /home/ang/GPTCast/logs/train/runs/2026-03-13_1...
# 3  new_phuber_tokenizer  /home/ang/GPTCast/logs/train/runs/2026-03-13_1...
# 4     old_mae_tokenizer  /home/ang/GPTCast/logs/train/runs/2026-03-13_1...
# 5  new_phuber_tokenizer  /home/ang/GPTCast/logs/train/runs/2026-03-13_1...
#
#               tag  best_step  best_value  last_step  last_value
# 0    val/rec_loss   152891.0    0.114190   164399.0    0.117187
# 1    val/rec_loss   144671.0    0.000134   164399.0    0.000141
# 2      val/p_loss   161111.0    0.007925   164399.0    0.008010
# 3      val/p_loss   156179.0    0.003566   164399.0    0.003646
# 4  val/quant_loss   162755.0    0.061975   164399.0    0.062813
# 5  val/quant_loss   162755.0    0.001819   164399.0    0.001963
