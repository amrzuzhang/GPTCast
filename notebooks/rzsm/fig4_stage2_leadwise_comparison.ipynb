# %% [markdown]
# # Fig. 4 第二阶段 lead-wise 对比
#
# 这个 notebook 生成第二阶段主文定量主图：
# - persistence
# - clean baseline
# - physical-context-aware static enhancement
# 在不同 lead 上的 RMSE / MAE 对照，以及 static 相对 baseline 的收益。

# %%
import sys
from pathlib import Path
from IPython.display import Image, Markdown, display


def find_gptcast_root(start: Path) -> Path:
    p = start.resolve()
    for _ in range(8):
        if (p / 'gptcast').is_dir():
            return p
        if (p / 'GPTCast' / 'gptcast').is_dir():
            return (p / 'GPTCast').resolve()
        p = p.parent
    return start.resolve()


ROOT = find_gptcast_root(Path.cwd())
NOTEBOOK_DIR = ROOT / 'notebooks' / 'rzsm'
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))
if str(NOTEBOOK_DIR) not in sys.path:
    sys.path.insert(0, str(NOTEBOOK_DIR))

from soilcast_stage2_paper_figures import load_eval_bundle, make_stage2_leadwise_figure

# %%
output_dir = ROOT / 'outputs' / 'stage2_forecaster_paper'

# 修改为你自己的正式 eval 输出目录
baseline_eval_dir = ROOT / 'outputs' / 'REPLACE_ME_BASELINE_EVAL_DIR'
static_eval_dir = ROOT / 'outputs' / 'REPLACE_ME_STATIC_EVAL_DIR'

baseline_bundle = load_eval_bundle('baseline', baseline_eval_dir)
static_bundle = load_eval_bundle('physical_context', static_eval_dir)
lead_df, fig_summary = make_stage2_leadwise_figure(
    baseline_bundle=baseline_bundle,
    static_bundle=static_bundle,
    output_dir=output_dir,
    save_stem='fig4_stage2_leadwise_comparison',
)
print('已生成图:', fig_summary['png_path'])
display(Image(filename=fig_summary['png_path']))
display(Markdown('**建议英文 caption：**'))
display(Markdown(fig_summary['caption_en']))
display(Markdown('**建议中文 caption：**'))
display(Markdown(fig_summary['caption_zh']))
